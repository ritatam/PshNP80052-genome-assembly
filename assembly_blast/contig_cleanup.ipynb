# %%
import os 
import pandas as pd

# %%
# load d-genies association table for chromosome assignment based on homology to Pst104E
df = pd.read_csv("psh_nepal.hic.hap12.p_ctg_Pst104E-1_assoc.tsv", sep="\t")
# load blast results
blast = pd.read_csv("all.blast", sep="\t", header=None, names="qseqid sseqid stitle length qcovs pident qstart qend sstart send sscinames staxids evalue".split(" "))
blast["pident"] = blast["pident"].astype(float)
# load windowed coverage
cov = pd.read_csv("coverage/window-stats.tsv", sep="\t", usecols=(0,2))

# %%
blast
# Out:
#                qseqid                             sseqid  \
# 0       h1tg000001l_0  gi|2234918871|ref|XM_047955534.1|
# 1       h1tg000001l_0  gi|2234918871|ref|XM_047955534.1|
# 2       h1tg000001l_0  gi|2234918871|ref|XM_047955534.1|
# 3       h1tg000001l_0  gi|2234918871|ref|XM_047955534.1|
# 4       h1tg000001l_0  gi|2234918871|ref|XM_047955534.1|
# ...               ...                                ...
# 106538    h2tg000110l       gi|2413979308|gb|CP110423.1|
# 106539    h2tg000110l       gi|2413979308|gb|CP110423.1|
# 106540    h2tg000110l       gi|2413979308|gb|CP110423.1|
# 106541    h2tg000110l        gi|334361375|gb|HM147441.1|
# 106542    h2tg000110l        gi|311306089|gb|HQ012475.1|
#
#                                                    stitle  length  qcovs  \
# 0       Puccinia striiformis f. sp. tritici uncharacte...    4069      1
# 1       Puccinia striiformis f. sp. tritici uncharacte...    2799      1
# 2       Puccinia striiformis f. sp. tritici uncharacte...    2190      1
# 3       Puccinia striiformis f. sp. tritici uncharacte...     894      1
# 4       Puccinia striiformis f. sp. tritici uncharacte...     507      1
# ...                                                   ...     ...    ...
# 106538       Puccinia triticina strain Pt15 chromosome 3A     426      6
# 106539       Puccinia triticina strain Pt15 chromosome 3A     119      6
# 106540       Puccinia triticina strain Pt15 chromosome 3A     105      6
# 106541  Puccinia striiformis voucher DAOM 240067 cytoc...     371      1
# 106542  Puccinia striiformis voucher RS479 cytochrome ...     371      1
#
#          pident  qstart    qend   sstart     send  \
# 0       100.000  241613  245681     7679     3611
# 1        99.964  237259  240057    11748     8950
# 2        99.954  247054  249243     2642      453
# 3        99.888  240152  241045     8949     8056
# 4       100.000  236486  236992    12362    11856
# ...         ...     ...     ...      ...      ...
# 106538   83.099   22413   22826  6796602  6796196
# 106539   95.798   22155   22273  6798119  6798003
# 106540   84.762   23131   23231  6795943  6795840
# 106541   98.922   17103   17473      371        1
# 106542   98.922   17103   17473      371        1
#
#                                   sscinames staxids        evalue
# 0       Puccinia striiformis f. sp. tritici  168172  0.000000e+00
# 1       Puccinia striiformis f. sp. tritici  168172  0.000000e+00
# 2       Puccinia striiformis f. sp. tritici  168172  0.000000e+00
# 3       Puccinia striiformis f. sp. tritici  168172  0.000000e+00
# 4       Puccinia striiformis f. sp. tritici  168172  0.000000e+00
# ...                                     ...     ...           ...
# 106538                   Puccinia triticina  208348  3.100000e-92
# 106539                   Puccinia triticina  208348  1.200000e-41
# 106540                   Puccinia triticina  208348  2.080000e-14
# 106541                 Puccinia striiformis   27350  0.000000e+00
# 106542                 Puccinia striiformis   27350  0.000000e+00
#
# [106543 rows x 13 columns]

# %%
# get mtDNA contigs with pident with mtDNA reference >= 80
mtDNA = blast[(blast["stitle"].str.contains("mitochondr", case=False)) & (blast["pident"]>=80)]
mtDNA_contigs = list(mtDNA["qseqid"].unique())

# check if there are contigs longer than 1Mbp with mtDNA hits (whose name contains "_" as they are split into chunks)
# these can be from NUMTs and will not be identified as mtDNA contig subsequently
for n in mtDNA_contigs:
    if "_" in n:
        print(n)
# Out:
# h1tg000012l_5
# h1tg000015l_0
# h1tg000019l_4
# h2tg000011l_4
# h2tg000017l_3

# %%
# get mean window coverage per contig
cov.columns = ["Query", "mean_cov"]
cov["Query"] = cov["Query"].apply(lambda x: x.split(":")[0])
cov["mean_cov"] = cov["mean_cov"].astype(float)
mean_cov_per_ctg = cov.groupby("Query")["mean_cov"].mean().reset_index()
mean_cov_per_ctg
# Out:
#            Query    mean_cov
# 0    h1tg000001l   46.698550
# 1    h1tg000002l   48.978347
# 2    h1tg000003l   48.449069
# 3    h1tg000004l   80.062176
# 4    h1tg000005l   48.358627
# ..           ...         ...
# 570  h2tg000106l  102.109643
# 571  h2tg000107l   28.979941
# 572  h2tg000108l   77.624064
# 573  h2tg000109l  192.374874
# 574  h2tg000110l   63.770868
#
# [575 rows x 2 columns]

# %%
df2 = pd.merge(df, mean_cov_per_ctg, on="Query")
df2["has_mtDNA_hit"] = df2["Query"].isin(mtDNA_contigs)
df2
# Out:
#            Query Target Strand  Q-len Q-start Q-stop    T-len  T-start  \
# 0    h1tg000033l   chr1      +  10228    7047   9924  5601519  1438413
# 1    h1tg000137l   chr1      +   8885    2095   2152  5601519  1438413
# 2    h1tg000139l   chr1      -   4668     920    977  5601519  1438413
# 3    h1tg000172l   chr1      +   4203    2499   2556  5601519  1438413
# 4    h1tg000302l   chr1      -   6285     464    521  5601519  1438413
# ..           ...    ...    ...    ...     ...    ...      ...      ...
# 570  h1tg000447l    NaN      +   9670      na     na       na       na
# 571  h1tg000451l    NaN      +   3961      na     na       na       na
# 572  h2tg000044l    NaN      +   6126      na     na       na       na
# 573  h2tg000091l    NaN      +  11329      na     na       na       na
# 574  h2tg000106l    NaN      +  17462      na     na       na       na
#
#       T-stop    mean_cov  has_mtDNA_hit
# 0    1438470   46.647622           True
# 1    1438470   54.380979           True
# 2    1438470    9.726435           True
# 3    1438470   16.400428           True
# 4    1438470   19.418775           True
# ..       ...         ...            ...
# 570       na   16.511789           True
# 571       na   15.529159          False
# 572       na    8.375612           True
# 573       na   22.453403          False
# 574       na  102.109643          False
#
# [575 rows x 11 columns]

# %%
filt = df2[(df2["mean_cov"]>=10)&(df2["Q-len"]>=20000)&(df2["has_mtDNA_hit"]==False)]
filt
# Out:
#            Query Target Strand    Q-len Q-start   Q-stop    T-len T-start  \
# 12   h1tg000002l   chr1      +  5377875    1011  5377134  5601519    3184
# 13   h2tg000001l   chr1      +  5405112     451  5404755  5601519    4100
# 14   h1tg000012l   chr2      -  5389257   90309  5385183  5438820    1099
# 15   h2tg000004l   chr2      -  5598330   63601  5596317  5438820    1086
# 68   h2tg000003l   chr3      -  5353409     372  5345288  5383601    8495
# ..           ...    ...    ...      ...     ...      ...      ...     ...
# 500  h2tg000009l  chr16      +  3063723   14082  3040924  3164667    2162
# 501  h1tg000007l  chr17      +  2591081    4641  2590322  2843575     944
# 502  h2tg000007l  chr17      +  2603707    3990  2603316  2843575     944
# 504  h1tg000001l  chr18      -  2525688    1119  2525185  2627259    9431
# 505  h2tg000016l  chr18      -  2594089     390  2593586  2627259   13070
#
#       T-stop   mean_cov  has_mtDNA_hit
# 12   5598249  48.978347          False
# 13   5599704  48.304371          False
# 14   5404098  49.325045          False
# 15   5404098  48.680548          False
# 68   5380796  47.697853          False
# ..       ...        ...            ...
# 500  3114714  47.968409          False
# 501  2828860  48.741996          False
# 502  2829896  48.552408          False
# 504  2608670  46.698550          False
# 505  2608670  48.270520          False
#
# [78 rows x 11 columns]

# %%
df2.to_csv("coverage/psh_nepal.hic.hap12.p_ctg_Pst10W4E-1_assoc_raw.tsv", sep="\t", index=None)
filt.to_csv("coverage/psh_nepal.hic.hap12.p_ctg_Pst104E-1_assoc_filtered.tsv", sep="\t", index=None)

# %% [markdown]
# seqtk subseq ../psh_nepal.hic.hap12.p_ctg.fasta psh_nepal.hic.hap12.p_ctg_Pst104E-1_assoc_filtered.contig_names.txt > psh_nepal.v2.filtered_contigs.fasta
